# %%
import folium
import math

# %%
# lat & longs of center of captured images
locations = {
    'Noel': [
    (32.8353107,-117.1939721), 
    (32.8353005,-117.1921541),
    (32.835252,-117.1905991),
    (32.8371028,-117.1880858),
    (32.8385846,-117.1869454), #5
    (32.839643,-117.1870219),
    (32.8264453,-117.1832565),
    (32.7844412,-117.1668956),
    (32.7862222,-117.1661486),
    (32.7937215,-117.1754918), #10
    (32.7952621,-117.1754151),
    (32.7950809,-117.1676967),
    (32.7806203,-117.2044161),
    (32.7768463,-117.2016394),
    (32.7760929,-117.1929139), #15
    (32.776029,-117.1959058),
    (32.7667972,-117.1910794),
    (32.7919718,-117.0908485),
    (32.7913077,-117.0900226),
    (32.7965164,-117.0835183), #20
    (32.7974655,-117.0695503), 
    (32.7956924,-117.0663954),
    (32.8051316,-117.0219805),
    (32.8063108,-117.0209906),
    (32.8052109,-117.0193553),
    (32.8062484,-117.0119538) #26
],

    'Josh': [],

    'Alex': [
        (32.741877,-117.125034),
        (32.741877,-117.126754),
        (32.743327,-117.125034),
        (32.743327,-117.126754),
        (32.7439375,-117.0935763),
        (32.7439375,-117.0952963),
        (32.7439375,-117.0970163),
        (32.7439375,-117.0987363),
        (32.7439375,-117.1004563),
        (32.7453875,-117.0935763),
        (32.7453875,-117.0952963),
        (32.7453875,-117.0970163),
        (32.7453875,-117.0987363),
        (32.7453875,-117.1004563),
        (32.7468375,-117.0935763),
        (32.7468375,-117.0952963),
        (32.7482875,-117.0935763),
        (32.7482875,-117.0952963),
        (32.7482875,-117.0970163),
        (32.7482875,-117.0987363),
        (32.7497375,-117.0935763),
        (32.7497375,-117.0952963),
        (32.7497375,-117.0987363),
    ],

    'Lauren': [
        (32.668738, -117.090566), 
        (32.668738, -117.092286),
        (32.668738, -117.094006),
        (32.668738, -117.095726), 
        (32.668738, -117.097446), 
        (32.670188, -117.090566), 
        (32.670188, -117.092286), 
        (32.670188, -117.094006), 
        (32.670188, -117.095726), 
        (32.670188, -117.097446), 
        (32.671638, -117.090566), 
        (32.671638, -117.092286), 
        (32.671638, -117.094006), 
        (32.671638, -117.095726),
        (32.671638, -117.097446),
        (32.673088, -117.090566), 
        (32.673088, -117.092286),
        (32.673088, -117.094006), 
        (32.673088, -117.095726), 
        (32.673088, -117.097446), 
        (32.674538, -117.090566), 
        (32.674538, -117.092286), 
        (32.674538, -117.094006), 
        (32.674538, -117.095726), 
        (32.674538, -117.097446)
    ]
}

# %%
# Calculate the boundaries of the tile
def calculate_bounds(lat, lon, zoom = 19, size = "640x640", scale = 2):
    """
    Calculate the boundaries of a square tile in geographical coordinates.

    """
    parallel_multiplier = math.cos(lat * math.pi / 180)
    degrees_per_pixel_x = 360 / math.pow(2, zoom + 8)
    degrees_per_pixel_y = 360 / math.pow(2, zoom + 8) * parallel_multiplier

    half_tile_size = size / scale

    delta_lat = degrees_per_pixel_y * half_tile_size
    delta_lon = degrees_per_pixel_x * half_tile_size

    lat_min = lat - delta_lat
    lat_max = lat + delta_lat
    lon_min = lon - delta_lon
    lon_max = lon + delta_lon

    return ((lat_min, lon_min), (lat_max, lon_max))

# %%
# Creates a map centered around San Diego
map_sd = folium.Map(location=[32.7157, -117.1611], zoom_start=11)

# For each location, calculate the boundary and add a rectangle
for name in locations:

    if name == 'Noel':
        color = 'blue'
    elif name == 'Alex':
        color = 'red'
    elif name == 'Lauren':
        color = 'yellow'
    else:
        color = 'green'

    for lat, long in locations[name]:
        
        bounds = calculate_bounds(lat, long, zoom=19, size=640)
        
        # Create a rectangle and add to the map
        folium.Rectangle(
            bounds=bounds,
            color=color,
            fill=True,
            fill_opacity=0.3,
            popup=folium.Popup(str(lat) + ", " + str(long))
        ).add_to(map_sd)

# %%
# Basic view of training image locations
map_sd
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51b0bf9267dfc4566374ce7a06201b7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51b0bf9267dfc4566374ce7a06201b7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51b0bf9267dfc4566374ce7a06201b7b = L.map(
#                 &quot;map_51b0bf9267dfc4566374ce7a06201b7b&quot;,
#                 {
#                     center: [32.7157, -117.1611],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fdf96cd661c7324776468a6d59b3e12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5fdf96cd661c7324776468a6d59b3e12.addTo(map_51b0bf9267dfc4566374ce7a06201b7b);
#
#
#             var rectangle_4adebfcc2b9353e2c1ed2d3f573af1f7 = L.rectangle(
#                 [[32.83458952257836, -117.19483040688476], [32.83603187742164, -117.19311379311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51b0bf9267dfc4566374ce7a06201b7b);
#
#
#         var popup_332675158e6b45c2625142b988951081 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1f0d79f6036481d3d13277046fbc600 = $(`&lt;div id=&quot;html_b1f0d79f6036481d3d13277046fbc600&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353107, -117.1939721&lt;/div&gt;`)[0];
#                 popup_332675158e6b45c2625142b988951081.setContent(html_b1f0d79f6036481d3d13277046fbc600);
#
#
#
#         rectangle_4adebfcc2b9353e2c1ed2d3f573af1f7.bindPopup(popup_332675158e6b45c2625142b988951081)
#         ;
#
#
#
#
#             var rectangle_52595e66fcee683a3968302b07545ad7 = L.rectangle(
#                 [[32.834579322495514, -117.19301240688476], [32.83602167750449, -117.19129579311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51b0bf9267dfc4566374ce7a06201b7b);
#
#
#         var popup_b9e548f7776dd4916c05579b6f0e8367 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85dc73c5963bb1ee81e7103655f08efd = $(`&lt;div id=&quot;html_85dc73c5963bb1ee81e7103655f08efd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353005, -117.1921541&lt;/div&gt;`)[0];
#                 popup_b9e548f7776dd4916c05579b6f0e8367.setContent(html_85dc73c5963bb1ee81e7103655f08efd);
#
#
#
#         rectangle_52595e66fcee683a3968302b07545ad7.bindPopup(popup_b9e548f7776dd4916c05579b6f0e8367)
#         ;
#
#
#
#
#             var rectangle_eb753adc89d194aa04fe2ce8863d86bd = L.rectangle(
#                 [[32.83453082210156, -117.19145740688477], [32.83597317789843, -117.18974079311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51b0bf9267dfc4566374ce7a06201b7b);
#
#
#         var popup_3ac00de078cd4d6c7f84a4059b4014f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a57fe063262ca508733f9f3f6c4bd93c = $(`&lt;div id=&quot;html_a57fe063262ca508733f9f3f6c4bd93c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.835252, -117.1905991&lt;/div&gt;`)[0];
#                 popup_3ac00de078cd4d6c7f84a4059b4014f0.setContent(html_a57fe063262ca508733f9f3f6c4bd93c);
#
#
#
#         rectangle_eb753adc89d194aa04fe2ce8863d86bd.bindPopup(popup_3ac00de078cd4d6c7f84a4059b4014f0)
#         ;
#
#
#
#
#             var rectangle_ed23f692bad6c452ec832eccee465d7f = L.rectangle(

# %%
# Satellite imagery #1 of training image locations

folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = False,
        control = True
       ).add_to(map_sd)

map_sd
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51b0bf9267dfc4566374ce7a06201b7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51b0bf9267dfc4566374ce7a06201b7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51b0bf9267dfc4566374ce7a06201b7b = L.map(
#                 &quot;map_51b0bf9267dfc4566374ce7a06201b7b&quot;,
#                 {
#                     center: [32.7157, -117.1611],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fdf96cd661c7324776468a6d59b3e12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5fdf96cd661c7324776468a6d59b3e12.addTo(map_51b0bf9267dfc4566374ce7a06201b7b);
#
#
#             var rectangle_4adebfcc2b9353e2c1ed2d3f573af1f7 = L.rectangle(
#                 [[32.83458952257836, -117.19483040688476], [32.83603187742164, -117.19311379311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51b0bf9267dfc4566374ce7a06201b7b);
#
#
#         var popup_332675158e6b45c2625142b988951081 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1f0d79f6036481d3d13277046fbc600 = $(`&lt;div id=&quot;html_b1f0d79f6036481d3d13277046fbc600&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353107, -117.1939721&lt;/div&gt;`)[0];
#                 popup_332675158e6b45c2625142b988951081.setContent(html_b1f0d79f6036481d3d13277046fbc600);
#
#
#
#         rectangle_4adebfcc2b9353e2c1ed2d3f573af1f7.bindPopup(popup_332675158e6b45c2625142b988951081)
#         ;
#
#
#
#
#             var rectangle_52595e66fcee683a3968302b07545ad7 = L.rectangle(
#                 [[32.834579322495514, -117.19301240688476], [32.83602167750449, -117.19129579311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51b0bf9267dfc4566374ce7a06201b7b);
#
#
#         var popup_b9e548f7776dd4916c05579b6f0e8367 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85dc73c5963bb1ee81e7103655f08efd = $(`&lt;div id=&quot;html_85dc73c5963bb1ee81e7103655f08efd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353005, -117.1921541&lt;/div&gt;`)[0];
#                 popup_b9e548f7776dd4916c05579b6f0e8367.setContent(html_85dc73c5963bb1ee81e7103655f08efd);
#
#
#
#         rectangle_52595e66fcee683a3968302b07545ad7.bindPopup(popup_b9e548f7776dd4916c05579b6f0e8367)
#         ;
#
#
#
#
#             var rectangle_eb753adc89d194aa04fe2ce8863d86bd = L.rectangle(
#                 [[32.83453082210156, -117.19145740688477], [32.83597317789843, -117.18974079311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51b0bf9267dfc4566374ce7a06201b7b);
#
#
#         var popup_3ac00de078cd4d6c7f84a4059b4014f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a57fe063262ca508733f9f3f6c4bd93c = $(`&lt;div id=&quot;html_a57fe063262ca508733f9f3f6c4bd93c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.835252, -117.1905991&lt;/div&gt;`)[0];
#                 popup_3ac00de078cd4d6c7f84a4059b4014f0.setContent(html_a57fe063262ca508733f9f3f6c4bd93c);
#
#
#
#         rectangle_eb753adc89d194aa04fe2ce8863d86bd.bindPopup(popup_3ac00de078cd4d6c7f84a4059b4014f0)
#         ;
#
#
#
#
#             var rectangle_ed23f692bad6c452ec832eccee465d7f = L.rectangle(

# %%
# Satellite imagery #2 of training image locations

#token = "pk.eyJ1IjoicGFwYS1ub2VsIiwiYSI6ImNsczNndnRpZzA4M2wybG8zNjZmY213aXEifQ.oY9R8zUP4EM0y3FxmeF9Dg" # your mapbox token
token = "pk.eyJ1IjoicGFwYS1ub2VsIiwiYSI6ImNsczNqeG16ZDB5N3oya281ZDZna2l6OHUifQ.795EdPmtQcyrIoHVBvWDEA"
tileurl = 'https://api.mapbox.com/v4/mapbox.satellite/{z}/{x}/{y}@2x.png?access_token=' + token

m = folium.Map(
    location=[32.7157, -117.1611], 
    zoom_start=11, 
    tiles=tileurl, 
    attr='Mapbox')

# For each location, calculate the boundary and add a rectangle
for name in locations:

    if name == 'Noel':
        color = 'blue'
    elif name == 'Alex':
        color = 'red'
    elif name == 'Lauren':
        color = 'yellow'
    else:
        color = 'green'

    for lat, long in locations[name]:
        
        bounds = calculate_bounds(lat, long, zoom=19, size=640)
        
        # Create a rectangle and add to the map
        folium.Rectangle(
            bounds=bounds,
            color=color,
            fill=True,
            fill_opacity=0.3,
            popup=folium.Popup(str(lat) + ", " + str(long))
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e075028cbd739e8affff2c09a5ac6dad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e075028cbd739e8affff2c09a5ac6dad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e075028cbd739e8affff2c09a5ac6dad = L.map(
#                 &quot;map_e075028cbd739e8affff2c09a5ac6dad&quot;,
#                 {
#                     center: [32.7157, -117.1611],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4199f94103fb8996b582ce66dac4ccb3 = L.tileLayer(
#                 &quot;https://api.mapbox.com/v4/mapbox.satellite/{z}/{x}/{y}@2x.png?access_token=pk.eyJ1IjoicGFwYS1ub2VsIiwiYSI6ImNsczNqeG16ZDB5N3oya281ZDZna2l6OHUifQ.795EdPmtQcyrIoHVBvWDEA&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4199f94103fb8996b582ce66dac4ccb3.addTo(map_e075028cbd739e8affff2c09a5ac6dad);
#
#
#             var rectangle_7f7a4a234d7251db8870695a7007f6bd = L.rectangle(
#                 [[32.83458952257836, -117.19483040688476], [32.83603187742164, -117.19311379311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e075028cbd739e8affff2c09a5ac6dad);
#
#
#         var popup_3605555505b8539d1785dd08086a8b90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28eb01bf32ac69605302b67a6c393635 = $(`&lt;div id=&quot;html_28eb01bf32ac69605302b67a6c393635&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353107, -117.1939721&lt;/div&gt;`)[0];
#                 popup_3605555505b8539d1785dd08086a8b90.setContent(html_28eb01bf32ac69605302b67a6c393635);
#
#
#
#         rectangle_7f7a4a234d7251db8870695a7007f6bd.bindPopup(popup_3605555505b8539d1785dd08086a8b90)
#         ;
#
#
#
#
#             var rectangle_cb158208155390f3a88d03acd48ec455 = L.rectangle(
#                 [[32.834579322495514, -117.19301240688476], [32.83602167750449, -117.19129579311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e075028cbd739e8affff2c09a5ac6dad);
#
#
#         var popup_c5dc3a6ebe7e5d2a38516efd85a5d1b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30f04d5b4a96c6fd73a522a27be92b68 = $(`&lt;div id=&quot;html_30f04d5b4a96c6fd73a522a27be92b68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353005, -117.1921541&lt;/div&gt;`)[0];
#                 popup_c5dc3a6ebe7e5d2a38516efd85a5d1b6.setContent(html_30f04d5b4a96c6fd73a522a27be92b68);
#
#
#
#         rectangle_cb158208155390f3a88d03acd48ec455.bindPopup(popup_c5dc3a6ebe7e5d2a38516efd85a5d1b6)
#         ;
#
#
#
#
#             var rectangle_40bef0ae4a4f002838fcbfef63d4a920 = L.rectangle(
#                 [[32.83453082210156, -117.19145740688477], [32.83597317789843, -117.18974079311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e075028cbd739e8affff2c09a5ac6dad);
#
#
#         var popup_2ef45154f6323c03be3898215c7126d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_856609ac1acf5eed1463fb9014f02145 = $(`&lt;div id=&quot;html_856609ac1acf5eed1463fb9014f02145&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.835252, -117.1905991&lt;/div&gt;`)[0];
#                 popup_2ef45154f6323c03be3898215c7126d8.setContent(html_856609ac1acf5eed1463fb9014f02145);
#
#
#
#         rectangle_40bef0ae4a4f002838fcbfef63d4a920.bindPopup(popup_2ef45154f6323c03be3898215c7126d8)
#         ;
#
#
#
#
#             var rectangle_bcfd40d4580b561333377dbaa6892dee = L.rectangle(

# %%
# Satellite imagery #3 of training image locations

google_map = folium.Map(
                tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
                attr = 'Google',
                name = 'Google Satellite',
                overlay = True,
                control = True,
                location=[32.7157, -117.1611], 
                zoom_start=11
                )

# For each location, calculate the boundary and add a rectangle
for name in locations:

    if name == 'Noel':
        color = 'blue'
    elif name == 'Alex':
        color = 'red'
    elif name == 'Lauren':
        color = 'yellow'
    else:
        color = 'green'

    for lat, long in locations[name]:
        
        bounds = calculate_bounds(lat, long, zoom=19, size=640)
        
        # Create a rectangle and add to the map
        folium.Rectangle(
            bounds=bounds,
            color=color,
            fill=True,
            fill_opacity=0.3,
            popup=folium.Popup(str(lat) + ", " + str(long))
        ).add_to(google_map)

google_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc77c4b115b5114f5a76ef2ce19ded2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc77c4b115b5114f5a76ef2ce19ded2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc77c4b115b5114f5a76ef2ce19ded2c = L.map(
#                 &quot;map_bc77c4b115b5114f5a76ef2ce19ded2c&quot;,
#                 {
#                     center: [32.7157, -117.1611],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;Google Satellite&quot;,
#                     overlay: true,
#                     control: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b518aaf94f099e50f27a2c7d5907424 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7b518aaf94f099e50f27a2c7d5907424.addTo(map_bc77c4b115b5114f5a76ef2ce19ded2c);
#
#
#             var rectangle_5828ccd0d7037935084dc1c38845479b = L.rectangle(
#                 [[32.83458952257836, -117.19483040688476], [32.83603187742164, -117.19311379311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc77c4b115b5114f5a76ef2ce19ded2c);
#
#
#         var popup_b68d810760f551ac8e9a73e0511d9b62 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0dee37cba10991a38853cf91b2b70e18 = $(`&lt;div id=&quot;html_0dee37cba10991a38853cf91b2b70e18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353107, -117.1939721&lt;/div&gt;`)[0];
#                 popup_b68d810760f551ac8e9a73e0511d9b62.setContent(html_0dee37cba10991a38853cf91b2b70e18);
#
#
#
#         rectangle_5828ccd0d7037935084dc1c38845479b.bindPopup(popup_b68d810760f551ac8e9a73e0511d9b62)
#         ;
#
#
#
#
#             var rectangle_2610652be47d111b1bf8dbaf92f5f8c8 = L.rectangle(
#                 [[32.834579322495514, -117.19301240688476], [32.83602167750449, -117.19129579311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc77c4b115b5114f5a76ef2ce19ded2c);
#
#
#         var popup_d4a9828328e22cbcab3eec9e7322b5eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc5b4781408713df7b9f3a3019e6a332 = $(`&lt;div id=&quot;html_cc5b4781408713df7b9f3a3019e6a332&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353005, -117.1921541&lt;/div&gt;`)[0];
#                 popup_d4a9828328e22cbcab3eec9e7322b5eb.setContent(html_cc5b4781408713df7b9f3a3019e6a332);
#
#
#
#         rectangle_2610652be47d111b1bf8dbaf92f5f8c8.bindPopup(popup_d4a9828328e22cbcab3eec9e7322b5eb)
#         ;
#
#
#
#
#             var rectangle_8b80f17a68e5592598ca6e472220bc3d = L.rectangle(
#                 [[32.83453082210156, -117.19145740688477], [32.83597317789843, -117.18974079311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc77c4b115b5114f5a76ef2ce19ded2c);
#
#
#         var popup_59c278a87b098f873e9e157194daceec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_baf3db052272e68dbaf8a8cdd606e111 = $(`&lt;div id=&quot;html_baf3db052272e68dbaf8a8cdd606e111&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.835252, -117.1905991&lt;/div&gt;`)[0];
#                 popup_59c278a87b098f873e9e157194daceec.setContent(html_baf3db052272e68dbaf8a8cdd606e111);
#
#
#
#         rectangle_8b80f17a68e5592598ca6e472220bc3d.bindPopup(popup_59c278a87b098f873e9e157194daceec)
#         ;
#
#
#
#
#             var rectangle_4842c3f7772609e0906e1e0a
